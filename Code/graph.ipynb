# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('351Bing_Complete_Modified.csv')

# %%
# df = df[['Date', 'Zipcode', 'Price', 'Space Ft2', 'Bedroom', 'Bathroom',
#        'Furnished', 'Laundry', 'Housing Type', 'Parking']]
df.head()
# Out:
#    Unnamed: 0    Date  Price  Space Ft2  Bedroom  Bathroom  Furnished  \
# 0           0  112917    650        850       20        10          0
# 1           1  121217    650        600       10        10          0
# 2           3  121217   1100       2120       30        15          0
# 3           4  120817    900        800       20        10          1
# 4           5  111917   2400       2000       30        25          0
#
#    Laundry  Housing Type  Parking       ...         LivingWall  LivingFloor  \
# 0        0             1        0       ...                  3            3
# 1        3             1        4       ...                  3            3
# 2        2             1        2       ...                  3            3
# 3        1             1        4       ...                  3            3
# 4        4             0        0       ...                  3            3
#
#    LivingFurn  BedWall  BedFloor  BedFurn  BathWall  BathFloor  BathFurn  \
# ...

# %%
sns.pairplot(df)

# %%
sns.pairplot(df)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Price', 'Space Ft2', 'Bedroom', 'Bathroom',
#        'Furnished', 'Laundry', 'Housing Type', 'Parking', 'Zipcode',
#        'Exterior', 'KitchenApp', 'KitchenWall', 'KitchenFloor', 'KitchenFurn',
#        'LivingWall', 'LivingFloor', 'LivingFurn', 'BedWall', 'BedFloor',
#        'BedFurn', 'BathWall', 'BathFloor', 'BathFurn', 'Student Housing'],
#       dtype='object')

# %%
sns.distplot(df['Price'], bins=20)

# %%
sns.jointplot(x='Space Ft2', y='Price', data=df, kind='hex')

# %%
sns.jointplot(x='Bedroom', y='Price', data=df, kind='reg')

# %%
sns.jointplot(x='Bathroom', y='Price', data=df, kind='reg')

# %%
sns.jointplot(x='Price', y='Housing Type', data=df)

# %%
# put categorical into hue
sns.pairplot(df, hue='Housing Type')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Price', 'Space Ft2', 'Bedroom', 'Bathroom',
#        'Furnished', 'Laundry', 'Housing Type', 'Parking', 'Zipcode',
#        'Exterior', 'KitchenApp', 'KitchenWall', 'KitchenFloor', 'KitchenFurn',
#        'LivingWall', 'LivingFloor', 'LivingFurn', 'BedWall', 'BedFloor',
#        'BedFurn', 'BathWall', 'BathFloor', 'BathFurn', 'Student Housing'],
#       dtype='object')

# %%
sns.barplot(x='Housing Type', y='Price', data=df)

# %%
sns.barplot(x='Student Housing', y='Price', data=df)

# %%
sns.countplot(x='Student Housing', data=df)

# %%
sns.countplot(x='Housing Type', data=df)
